# %%
#importing all the required libraries

import pandas as pd
import numpy as np

# %%
cars = pd.read_csv('2. Cars Data1.csv')
cars
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
obj = cars.dtypes
obj
# Out:
# Make            object
# Model           object
# Type            object
# Origin          object
# DriveTrain      object
# MSRP            object
# Invoice         object
# EngineSize     float64
# Cylinders      float64
# Horsepower     float64
# MPG_City       float64
# MPG_Highway    float64
# Weight         float64
# Wheelbase      float64
# Length         float64
# dtype: object

# %%
cars.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
mean_val = cars.mean()
mean_val
# Out:
# C:\Users\mskir\AppData\Local\Temp/ipykernel_1992/3432091260.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mean_val = cars.mean()
# EngineSize        3.196729
# Cylinders         5.807512
# Horsepower      215.885514
# MPG_City         20.060748
# MPG_Highway      26.843458
# Weight         3577.953271
# Wheelbase       108.154206
# Length          186.362150
# dtype: float64

# %%
fill_data = cars.fillna(value = mean_val, inplace = True)

# %%
cars.dropna(axis = 0, inplace = True)

# %%
cars.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %% [markdown]
# ### 2) Question ( Based on Value Counts )- Check what are the different types of Make are there in our dataset. And, what is the count (occurrence) of each Make in the data ?

# %%
#flitering 
brands = cars['Make'].unique()
brands
# Out:
# array(['Acura', 'Audi', 'BMW', 'Buick', 'Cadillac', 'Chevrolet',
#        'Chrysler', 'Dodge', 'Ford', 'GMC', 'Honda', 'Hummer', 'Hyundai',
#        'Infiniti', 'Isuzu', 'Jaguar', 'Jeep', 'Kia', 'Land Rover',
#        'Lexus', 'Lincoln', 'MINI', 'Mazda', 'Mercedes-Benz', 'Mercury',
#        'Mitsubishi', 'Nissan', 'Oldsmobile', 'Pontiac', 'Porsche', 'Saab',
#        'Saturn', 'Scion', 'Subaru', 'Suzuki', 'Toyota', 'Volkswagen',
#        'Volvo'], dtype=object)

# %%
brand_count = cars['Make'].value_counts(sort = True, ascending = False)
brand_count
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Dodge            13
# Mitsubishi       13
# Volvo            12
# Jaguar           12
# Hyundai          12
# Subaru           11
# Pontiac          11
# Mazda            11
# Lexus            11
# Kia              11
# Buick             9
# Mercury           9
# Lincoln           9
# Saturn            8
# Cadillac          8
# Suzuki            8
# Infiniti          8
# GMC               8
# Acura             7
# Porsche           7
# Saab              7
# Land Rover        3
# Oldsmobile        3
# Jeep              3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: Make, dtype: int64

# %% [markdown]
# ### 3) Instruction ( Filtering ) - Show all the records where Origin is Asia or Europe.

# %%
ori_A_E =  cars[(cars['Origin']=='Asia') | (cars['Origin']=='Europe')]
ori_A_E
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# ### 4) Instruction ( Removing unwanted records ) - Remove all the records (rows) where Weight is above 4000.

# %%
weig_4k = cars[cars['Weight'] > 4000]
weig_4k
# Out:
#            Make                           Model    Type  Origin DriveTrain  \
# 0         Acura                             MDX     SUV    Asia        All
# 15         Audi  A4 3.0 Quattro convertible 2dr   Sedan  Europe        All
# 17         Audi              A6 4.2 Quattro 4dr   Sedan  Europe        All
# 18         Audi                A8 L Quattro 4dr   Sedan  Europe        All
# 20         Audi                        RS 6 4dr  Sports  Europe      Front
# ..          ...                             ...     ...     ...        ...
# 405  Volkswagen                      Touareg V6     SUV  Europe        All
# 415  Volkswagen                     Phaeton 4dr   Sedan  Europe      Front
# 416  Volkswagen                 Phaeton W12 4dr   Sedan  Europe      Front
# 419  Volkswagen                       Passat W8   Wagon  Europe      Front
# 420       Volvo                         XC90 T6     SUV  Europe        All
#
# ...

# %% [markdown]
# ###  5) Instruction ( Applying function on a column ) - Increase all the values of 'MPG_City' column by 3.

# %%
add_val = cars['MPG_City']+3
add_val #this works only for temporary
# Out:
# 0      20.0
# 1      27.0
# 2      25.0
# 3      23.0
# 4      21.0
#        ...
# 427    24.0
# 428    23.0
# 429    22.0
# 430    25.0
# 431    23.0
# Name: MPG_City, Length: 432, dtype: float64

# %%
cars['MPG_City'] = cars['MPG_City'].apply(lambda x: x+3)

# %%
cars
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
# how many sedans have been sold in Asia? 
sed_asia = cars[(cars['Type']== 'Sedan') & (cars['Origin'] == 'Asia')].shape
sed_asia
# Out:
# (94, 15)

# %%
# how many volvo has been sold in total around the globe? 
volvo_sold = cars[cars['Make'] == 'Volvo'].shape
volvo_sold
# Out:
# (12, 15)

# %%
# what is the average lenght of the 'Mercedes-Benz' in Europe?
Benz_eur = cars[(cars['Make']== 'Mercedes-Benz') & (cars['Origin']== 'Europe')]
mean_val = Benz_eur['Length'].mean()
mean_val
# Out:
# 182.65384615384616

# %%
Benz_eur['Length'].describe()
# Out:
# count     26.000000
# mean     182.653846
# std       10.684352
# min      158.000000
# 25%      178.000000
# 50%      179.000000
# 75%      190.000000
# max      203.000000
# Name: Length, dtype: float64

# %%
# Max and min 'Horsepower' of 'Porsche' in various continents?
porsche = cars[cars['Make']== 'Porsche']
porsche_con = porche.groupby(by = 'Origin', as_index = True)['Horsepower']
porsche_con.describe()
# Out:
#         count        mean        std    min    25%    50%    75%    max
# Origin
# Europe    7.0  321.142857  78.975584  228.0  286.5  315.0  327.5  477.0

# %%
cars[cars['Make']=='Porsche']
# Out:
#         Make                                Model    Type  Origin DriveTrain  \
# 334  Porsche                            Cayenne S     SUV  Europe        All
# 335  Porsche  911 Carrera convertible 2dr (coupe)  Sports  Europe       Rear
# 336  Porsche   911 Carrera 4S coupe 2dr (convert)  Sports  Europe        All
# 337  Porsche                  911 Targa coupe 2dr  Sports  Europe       Rear
# 338  Porsche                          911 GT2 2dr  Sports  Europe       Rear
# 339  Porsche              Boxster convertible 2dr  Sports  Europe       Rear
# 340  Porsche            Boxster S convertible 2dr  Sports  Europe       Rear
#
#           MSRP    Invoice  EngineSize  Cylinders  Horsepower  MPG_City  \
# 334   $56,665    $49,865          4.5        8.0       340.0      17.0
# 335   $79,165    $69,229          3.6        6.0       315.0      21.0
# 336   $84,165    $72,206          3.6        6.0       315.0      20.0
# ...
